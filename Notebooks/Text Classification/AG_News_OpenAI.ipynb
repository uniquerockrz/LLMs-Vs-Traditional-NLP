# %%
from dotenv import load_dotenv
from openai import OpenAI
from datasets import load_dataset
import pandas as pd
from sklearn.metrics import accuracy_score, f1_score
import json

# %%
load_dotenv()
client = OpenAI()

# %%
completion = client.chat.completions.create(
    model='gpt-3.5-turbo-0125',
    messages=[
        {'role': 'system', 'content': 'You are a poetic assistant, skilled in explaining complex programming concepts with creative flair.'},
        {'role': 'user', 'content': 'Compose a poem that explains the concept of recursion in programming.'}
    ]
)

# %%
print(completion.choices[0].message)
# Out:
# ChatCompletionMessage(content="In the realm of loops and functions sublime,\nResides a technique quite divine,\nRecursion, a method of coding magic,\nA wondrous and powerful programming fabric.\n\nLike a mirror reflecting its own reflection,\nRecursion calls upon itself, with no objection,\nA function that calls itself, with grace,\nUnraveling problems in an elegant embrace.\n\nLike a Russian doll nested inside another,\nRecursion breaks problems down like a brother,\nDivide and conquer, the strategy it employs,\nSolving complexity with recursive joys.\n\nA dance of functions repeating in endless fashion,\nSolving puzzles with recursive passion,\nBase cases to break the cycle's hold,\nIn recursion's intricate tale, beautifully told.\n\nSo tread carefully in this recursive terrain,\nFor in its depths lies both pleasure and pain,\nBut wield it with care, let creativity soar,\nFor recursion's beauty, forevermore.", role='assistant', function_call=None, tool_calls=None)

# %%
tools = [
    {
        "type": "function",
        "function": {
            "name": "get_classification_of_news_article",
            "description": "Get classification of news article",
            "parameters": {
                "type": "object",
                "properties": {
                    "classification": {
                        "type": "string",
                        "description": "the classification label of the news article",
                        "enum": [
                            "world",
                            "sports",
                            "business",
                            "technology",
                            "science"
                        ]   
                    }
                },
                "required": [ "classification" ]
            }
        }
    }
]

# %%
dataset = load_dataset('ag_news')

# %%
# Let's convert them to dataframes
df_test = pd.DataFrame(dataset['test'])

# %%
df_test.head(10)
# Out:
#                                                 text  label
# 0  Fears for T N pension after talks Unions repre...      2
# 1  The Race is On: Second Private Team Sets Launc...      3
# 2  Ky. Company Wins Grant to Study Peptides (AP) ...      3
# 3  Prediction Unit Helps Forecast Wildfires (AP) ...      3
# 4  Calif. Aims to Limit Farm-Related Smog (AP) AP...      3
# 5  Open Letter Against British Copyright Indoctri...      3
# 6  Loosing the War on Terrorism \\"Sven Jaschan, ...      3
# 7  FOAFKey: FOAF, PGP, Key Distribution, and Bloo...      3
# 8  E-mail scam targets police chief Wiltshire Pol...      3
# 9  Card fraud unit nets 36,000 cards In its first...      3

# %%
completion = client.chat.completions.create(
    model='gpt-3.5-turbo-0125',
    messages=[
        {'role': 'system', 'content': 'You are an agent that classifies news articles into appropriate categories. Return the classification as world if no other classification is appropriate.'},
        {'role': 'user', 'content': 'Fears for T N pension after talks Unions representing workers at Turner   Newall say they are \'disappointed\' after talks with stricken parent firm Federal Mogul.'}
    ],
    tools=tools,
    tool_choice="auto"
)

# %%
json.loads(completion.choices[0].message.tool_calls[0].function.arguments)
# Out:
# {'classification': 'world'}

# %%
def get_openai_classification(news_text):
    completion = client.chat.completions.create(
        model='gpt-3.5-turbo-0125',
        messages=[
            {'role': 'system', 'content': 'You are an agent that classifies news articles into appropriate categories. Return the classification as world if no other classification is appropriate.'},
            {'role': 'user', 'content': f'{news_text}'}
        ],
        tools=tools,
        tool_choice='auto'
    )

    label = json.loads(completion.choices[0].message.tool_calls[0].function.arguments)['classification']
    
    if label == 'world':
        return 0
    if label == 'sports':
        return 1
    if label == 'business':
        return 2
    if label == 'technology':
        return 3
    if label == 'science':
        return 3

# %%
get_openai_classification(df_test.iloc[0].text)
# Out:
# 0

# %%
res_df_path = '../../data/openai_text_classification.csv'

# %%
res_df = pd.read_csv(res_df_path)

# %%
res_df.head(50)
# Out:
#     index                                               text  predicted_label  \
# 0       0  Fears for T N pension after talks Unions repre...              0.0
# 1       1  The Race is On: Second Private Team Sets Launc...              3.0
# 2       2  Ky. Company Wins Grant to Study Peptides (AP) ...              3.0
# 3       3  Prediction Unit Helps Forecast Wildfires (AP) ...              3.0
# 4       4  Calif. Aims to Limit Farm-Related Smog (AP) AP...              0.0
# 5       5  Open Letter Against British Copyright Indoctri...              3.0
# 6       6  Loosing the War on Terrorism \\"Sven Jaschan, ...              3.0
# 7       7  FOAFKey: FOAF, PGP, Key Distribution, and Bloo...              3.0
# 8       8  E-mail scam targets police chief Wiltshire Pol...              0.0
# 9       9  Card fraud unit nets 36,000 cards In its first...              2.0
# 10     10  Group to Propose New High-Speed Wireless Forma...              3.0
# 11     11  Apple Launches Graphics Software, Video Bundle...              3.0
# 12     12  Dutch Retailer Beats Apple to Local Download M...              2.0
# 13     13  Super ant colony hits Australia A giant 100km ...              3.0
# 14     14  Socialites unite dolphin groups Dolphin groups...              3.0
# 15     15  Teenage T. rex's monster growth Tyrannosaurus ...              3.0
# 16     16  Scientists Discover Ganymede has a Lumpy Inter...              3.0
# 17     17  Mars Rovers Relay Images Through Mars Express ...              3.0
# 18     18  Rocking the Cradle of Life When did life begin...              3.0
# 19     19  Storage, servers bruise HP earnings update Ear...              2.0
# 20     20  IBM to hire even more new workers By the end o...              2.0
# 21     21  Sun's Looking Glass Provides 3D View Developer...              3.0
# 22     22  IBM Chips May Someday Heal Themselves New tech...              3.0
# 23     23  Some People Not Eligible to Get in on Google I...              2.0
# 24     24  Rivals Try to Turn Tables on Charles Schwab By...              2.0
# 25     25  News: Sluggish movement on power grid cyber se...              3.0
# 26     26  Giddy Phelps Touches Gold for First Time Micha...              1.0
# 27     27  Tougher rules won't soften Law's game FOXBOROU...              1.0
# 28     28  Shoppach doesn't appear ready to hit the next ...              1.0
# 29     29  Mighty Ortiz makes sure Sox can rest easy Just...              1.0
# 30     30  They've caught his eye In  quot;helping themse...              1.0
# 31     31  Indians Mount Charge The Cleveland Indians pul...              1.0
# 32     32  Sister of man who died in Vancouver police cus...              0.0
# 33     33  Man Sought  #36;50M From McGreevey, Aides Say ...              2.0
# 34     34  Explosions Echo Throughout Najaf NAJAF, Iraq -...              0.0
# 35     35  Frail Pope Celebrates Mass at Lourdes LOURDES,...              0.0
# 36     36  Venezuela Prepares for Chavez Recall Vote Supp...              0.0
# 37     37  1994 Law Designed to Preserve Guard Jobs (AP) ...              0.0
# 38     38  Iran Warns Its Missiles Can Hit Anywhere in Is...              0.0
# 39     39  Afghan Army Dispatched to Calm Violence KABUL,...              0.0
# 40     40  Johnson Helps D-Backs End Nine-Game Slide (AP)...              1.0
# 41     41  Retailers Vie for Back-To-School Buyers (Reute...              2.0
# 42     42  Politics an Afterthought Amid Hurricane (AP) A...              0.0
# 43     43  Spam suspension hits Sohu.com shares (FT.com) ...              2.0
# 44     44  Erstad's Double Lifts Angels to Win (AP) AP - ...              1.0
# 45     45  Drew Out of Braves' Lineup After Injury (AP) A...              1.0
# 46     46  Venezuelans Flood Polls, Voting Extended  CARA...              0.0
# 47     47  Dell Exits Low-End China Consumer PC Market  H...              2.0
# 48     48  China Says Taiwan Spy Also Operated in U.S. - ...              0.0
# 49     49  Another Major Non-Factor Another major, anothe...              1.0
#
#     actual_label  execution_time
# 0              2        1.585969
# 1              3        1.012847
# 2              3        0.998038
# 3              3        1.043703
# 4              3        1.288217
# 5              3        0.963824
# 6              3        0.983094
# 7              3        0.907009
# 8              3        1.271042
# 9              3        1.034202
# 10             3        0.738263
# 11             3        1.407732
# 12             3        1.238503
# 13             3        0.950577
# 14             3        0.938702
# 15             3        1.136574
# 16             3        1.059130
# 17             3        0.956174
# 18             3        0.885886
# 19             3        1.228824
# 20             3        2.253975
# 21             3        1.080093
# 22             3        0.883689
# 23             3        1.343141
# 24             3        1.618801
# 25             3        1.069554
# 26             1        0.840560
# 27             1        0.941385
# 28             1        1.024134
# 29             1        0.935524
# 30             1        0.906642
# 31             1        1.049507
# 32             0        1.473137
# 33             0        1.158343
# 34             0        1.022947
# 35             0        0.917327
# 36             0        0.667922
# 37             0        1.692023
# 38             0        0.766465
# 39             0        0.972428
# 40             1        0.921017
# 41             2        1.433218
# 42             0        1.024327
# 43             3        0.967533
# 44             1        1.038221
# 45             1        0.859953
# 46             0        4.393302
# 47             3        1.361116
# 48             0        1.002694
# 49             1        1.023758

# %%
res_df['predicted_label'] = res_df['predicted_label'].fillna(0)

# %%
print(f'Total execution time {res_df['execution_time'].sum()} seconds')
# Out:
# Total execution time 872.2161402629827 seconds

# %%
print('Test Accuracy: {}'.format(
    accuracy_score(y_true=res_df['actual_label'], y_pred=res_df['predicted_label'])
))
# Out:
# Test Accuracy: 0.8257491675915649

# %%
print('Test f-score: {}'.format(
    f1_score(y_true=res_df['actual_label'], y_pred=res_df['predicted_label'], average='weighted'), 
))
# Out:
# Test f-score: 0.826007147952462
